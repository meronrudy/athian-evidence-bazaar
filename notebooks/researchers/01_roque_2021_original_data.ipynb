# %% [markdown]
# # Roque 2021 Original Data
#
# Executable notebook wrapper for the PLOS S1 workbook reconstruction.

# %%
import subprocess, sys
subprocess.run([sys.executable, 'examples/researchers/01_roque_2021/run.py'], check=True)
