# %% [markdown]
# # Intercontinental Prediction
#
# Executable notebook wrapper for the Niu et al. model-provenance case study.

# %%
import subprocess, sys
subprocess.run([sys.executable, 'examples/researchers/05_intercontinental_prediction/run.py'], check=True)
