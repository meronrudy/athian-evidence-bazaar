# %% [markdown]
# # Feed To Methane
#
# Executable notebook wrapper for the RationSmart feed-to-methane architecture.

# %%
import subprocess, sys
subprocess.run([sys.executable, 'examples/researchers/06_rationsmart/run.py'], check=True)
