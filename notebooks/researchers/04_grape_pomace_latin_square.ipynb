# %% [markdown]
# # Grape Pomace Latin Square
#
# Executable notebook wrapper for the Akter et al. 2025 case study.

# %%
import subprocess, sys
subprocess.run([sys.executable, 'examples/researchers/04_grape_pomace/run.py'], check=True)
