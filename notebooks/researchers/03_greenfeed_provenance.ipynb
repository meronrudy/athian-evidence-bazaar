# %% [markdown]
# # GreenFeed Provenance
#
# Executable notebook wrapper for the published-protocol case study.

# %%
import subprocess, sys
subprocess.run([sys.executable, 'examples/researchers/03_greenfeed_provenance/run.py'], check=True)
